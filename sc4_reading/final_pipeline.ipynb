# %%
import os
from pathlib import Path
import pandas as pd
from bin_to_parquet import run_pipeline
from add_elevaz_pipeline import run_sp3_pipeline
from lvl3_pipeline import run_lvl3_pipeline

# %%
def get_input():
    '''Get user input for the binary files'''
    binary_dir = input("Enter the path to the binary files:")
    latitude = float(input("Enter the latitude of the receiver: "))
    longitude = float(input("Enter the longitude of the receiver: "))
    height = float(input("Enter the height of the receiver: "))
    return binary_dir, latitude, longitude, height

# %%
def main():
    binary_dir, latitude, longitude, height = get_input()

    binary_dir = Path(binary_dir)
    txt_dir = binary_dir / "txt"
    mearem_dir = binary_dir / "mearem"
    lvl0_dir = binary_dir / "lvl0" 
    sp3_dir = binary_dir / "sp3"
    lvl2_dir = binary_dir / "lvl2"
    lvl3_dir = binary_dir / "lvl3"  

    print(f"\nBinary directory: {binary_dir}")

    run_pipeline(
        binary_dir=binary_dir,
        txt_dir=txt_dir,
        mearem_dir=mearem_dir,
        lvl0_dir=lvl0_dir
    )

    print("Binary to Parquet pipeline completed.")

    run_sp3_pipeline(
        parquet_dir=lvl0_dir,
        sp3_dir=sp3_dir,
        output_dir=lvl2_dir,
        rx_lat=latitude,
        rx_long=longitude,
        rx_hei=height
    )

    print("Elevation and Azimuth added to the parquet files.")

    run_lvl3_pipeline(
        lvl0_dir=lvl0_dir,
        lvl2_dir=lvl2_dir,
        lvl3_dir=lvl3_dir,
        mode="both",
        verbose=True
    )

    print("Level-3 pipeline completed.")

if __name__ == "__main__":
    main()
# Out:
# Enter the path to the binary files: /home/dal674840/scratch
# Enter the latitude of the receiver:  36.6783536
# Enter the longitude of the receiver:  -96.98346445
# Enter the height of the receiver:  146.916
# Binary directory: /home/dal674840/scratch
#
# Found 192 binary files.
#
# ================================================================================
# [1/192] mx01316a00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [2/192] mx01316a15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [3/192] mx01316a30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [4/192] mx01316a45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [5/192] mx01316b00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [6/192] mx01316b15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [7/192] mx01316b30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [8/192] mx01316b45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [9/192] mx01316c00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [10/192] mx01316c15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [11/192] mx01316c30.25_
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [12/192] mx01316c45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [13/192] mx01316d00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [14/192] mx01316d15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [15/192] mx01316d30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [16/192] mx01316d45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [17/192] mx01316e00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [18/192] mx01316e15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [19/192] mx01316e30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [20/192] mx01316e45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [21/192] mx01316f00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [22/192] mx01316f15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [23/192] mx01316f30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [24/192] mx01316f45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [25/192] mx01316g00.25_
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# Traceback (most recent call last):
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/bin_to_parquet.py", line 70, in run_pipeline
#     txt_file = binary_to_clean_txt(
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/scintkit/src/scintkit/sc4_reading/sc4_reading_func.py", line 44, in binary_to_clean_txt
#     result = sp.run(commands, capture_output=True, text=True, cwd=work_dir)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/home/dal674840/.conda/envs/scintkit_env/lib/python3.11/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [26/192] mx01316g15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [27/192] mx01316g30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [28/192] mx01316g45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [29/192] mx01316h00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [30/192] mx01316h15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [31/192] mx01316h30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [32/192] mx01316h45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [33/192] mx01316i00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [34/192] mx01316i15.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [35/192] mx01316i30.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [36/192] mx01316i45.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
# [37/192] mx01316j00.25_
# ✗ Failed
# [Errno 2] No such file or directory: 'rxtools_exec.sh'
# ================================================================================
#
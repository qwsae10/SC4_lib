# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
binary_folder = Path("/home/dal674840/scratch")

binary_files = sorted(binary_folder.glob("*.??_ "))   

for i, binary_file in enumerate(binary_files, start=1):

    print(f"\nProcessing {i}/{len(binary_files)}")
    print(binary_file.name)

    try:
        # Step 1: Binary -> TXT
        txt_file = sc4_reading_func(binary_file)

        # Step 2: TXT -> Parquet
        parquet_file = sc4_s02_txt2parquet(txt_file)

        # Step 3: Apply Level-0 processing
        final_output = pq_reading_lvl0(parquet_file)

        print(f"Finished {binary_file.name}")

    except Exception as e:
        print(f"Failed on {binary_file.name}")
        print(e)
